# %%
"""
create dataframe in PySpark
find avg. stock value on daily basis for each stock
find max avg stock value of each stock"""

Data = [("2023-01-01","AAPL", 150.00),
("2023-01-02","AAPL", 155.00),
("2023-01-01","GOOG", 2500.00),
("2023-01-02","GOOG", 2550.00),
("2023-01-01","MSFT", 300.00),
("2023-01-02","MSFT", 310.00)]

from pyspark.sql import SparkSession
from pyspark.sql.functions import *

Schema = ["date","stock","value"]

spark = SparkSession.builder.appName("stock").getOrCreate()

df = spark.createDataFrame(Data, schema = Schema)

# df1 = df.withColumn("date",to_date(col("date"),'yyyy-MM-dd'))
# df1.printSchema()

# df2 = df1.groupBy("stock","date").agg(avg("value").alias("avg_value"))
# df3 = df2.groupBy("stock").agg(max("avg_value").alias("max_stock_value"))
# df3.show()

df.createOrReplaceTempView("my_table")

result_sql = spark.sql("""WITH CTE AS(SELECT stock, CAST(date AS DATE) AS date,
                          AVG(value) AS avg_stock
                          FROM my_table
                          GROUP BY stock, date)
                          SELECT stock, MAX(avg_stock) AS max_stock
                          FROM CTE
                          GROUP BY stock """)

result_sql.show()
# Out:
# ---------------------------------------------------------------------------
# SparkConnectGrpcException                 Traceback (most recent call last)
# Cell In[1], line 20
#      16 Schema = ["date","stock","value"]
#      17
#      18 spark = SparkSession.builder.appName("stock").getOrCreate()
#      19
# ---> 20 df = spark.createDataFrame(Data, schema = Schema)
#      21
#      22 # df1 = df.withColumn("date",to_date(col("date"),'yyyy-MM-dd'))
#      23 # df1.printSchema()
#
# File ~\OneDrive\Desktop\python_program\.venv\Lib\site-packages\pyspark\sql\connect\session.py:608, in SparkSession.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     602         raise PySparkValueError(
#     603             errorClass="CANNOT_INFER_EMPTY_SCHEMA",
#     604             messageParameters={},
#     605         )
#     607 # Get all related configs in a batch
# --> 608 configs = self._client.get_config_dict(
#     609     "spark.sql.timestampType",
#     610     "spark.sql.session.timeZone",
#     611     "spark.sql.session.localRelationCacheThreshold",
#     612     "spark.sql.session.localRelationSizeLimit",
#     613     "spark.sql.session.localRelationChunkSizeRows",
#     614     "spark.sql.session.localRelationChunkSizeBytes",
#     615     "spark.sql.session.localRelationBatchOfChunksSizeBytes",
#     616     "spark.sql.execution.pandas.convertToArrowArraySafely",
#     617     "spark.sql.execution.pandas.inferPandasDictAsMap",
#     618     "spark.sql.pyspark.inferNestedDictAsStruct.enabled",
#     619     "spark.sql.pyspark.legacy.inferArrayTypeFromFirstElement.enabled",
#     620     "spark.sql.pyspark.legacy.inferMapTypeFromFirstPair.enabled",
#     621     "spark.sql.execution.arrow.useLargeVarTypes",
#     622 )
#     623 timezone = configs["spark.sql.session.timeZone"]
#     624 prefer_timestamp_ntz = configs["spark.sql.timestampType"] == "TIMESTAMP_NTZ"
#
# File ~\OneDrive\Desktop\python_program\.venv\Lib\site-packages\pyspark\sql\connect\client\core.py:2482, in SparkConnectClient.get_config_dict(self, *keys)
#    2480 def get_config_dict(self, *keys: str) -> Mapping[str, Optional[str]]:
#    2481     op = pb2.ConfigRequest.Operation(get=pb2.ConfigRequest.Get(keys=keys))
# -> 2482     return dict(self.config(op).pairs)
#
# File ~\OneDrive\Desktop\python_program\.venv\Lib\site-packages\pyspark\sql\connect\client\core.py:2525, in SparkConnectClient.config(self, operation)
#    2523     raise SparkConnectException("Invalid state during retry exception handling.")
#    2524 except Exception as error:
# -> 2525     self._handle_error(error)
#
# File ~\OneDrive\Desktop\python_program\.venv\Lib\site-packages\pyspark\sql\connect\client\core.py:2785, in SparkConnectClient._handle_error(self, error, operation_id)
#    2783 try:
#    2784     if isinstance(error, grpc.RpcError):
# -> 2785         self._handle_rpc_error(error)
#    2786     raise error
#    2787 except BaseException as handled_error:
#
# File ~\OneDrive\Desktop\python_program\.venv\Lib\site-packages\pyspark\sql\connect\client\core.py:2880, in SparkConnectClient._handle_rpc_error(self, rpc_error)
#    2877         d.Unpack(info)
#    2878         logger.debug(f"Received ErrorInfo: {info}")
# -> 2880         self._handle_rpc_error_with_error_info(info, status.message, status_code)  # EDGE
#    2882         raise convert_exception(
#    2883             info,
#    2884             status.message,
#    (...)   2887             status_code,
#    2888         ) from None
#    2890 raise SparkConnectGrpcException(
#    2891     message=status.message,
#    2892     sql_state=ErrorCode.CLIENT_UNEXPECTED_MISSING_SQL_STATE,  # EDGE
#    2893     grpc_status_code=status_code,
#    2894 ) from None
#
# File ~\OneDrive\Desktop\python_program\.venv\Lib\site-packages\pyspark\sql\connect\client\core.py:2934, in SparkConnectClient._handle_rpc_error_with_error_info(self, info, message, status_code)
#    2932     self._closed = True
#    2933 if error_class == "INVALID_PARAMETER_VALUE.INVALID_CLIENT_IMAGE_VERSION":
# -> 2934     raise SparkConnectGrpcException(
#    2935         "Serverless mode is not yet supported in this version of Databricks Connect. "
#    2936         "Information about version compatibility can be found at "
#    2937         "https://docs.databricks.com/aws/en/dev-tools/databricks-connect/requirements#databricks-connect-versions",  # noqa: E501
#    2938         sql_state=info.metadata.get("sqlState", default=ErrorCode.CLIENT_UNEXPECTED_MISSING_SQL_STATE),
#    2939         grpc_status_code=status_code,
#    2940     ) from None
#    2941 if '[PYTHON_VERSION_MISMATCH]' in message:
#    2942     raise SparkConnectGrpcException(
#    2943         "Python versions in the Spark Connect client and server are different. "
#    2944         "To execute user-defined functions, client and server should have the "
#    (...)   2952         grpc_status_code=status_code,
#    2953     ) from None
#
# SparkConnectGrpcException: Serverless mode is not yet supported in this version of Databricks Connect. Information about version compatibility can be found at https://docs.databricks.com/aws/en/dev-tools/databricks-connect/requirements#databricks-connect-versions
